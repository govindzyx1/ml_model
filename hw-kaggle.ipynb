# %%
import pandas as pd
import numpy as np
import matplotlib as ml
import seaborn as sns

# %%
data=pd.read_csv("LGBT_Survey_ViolenceAndHarassment.csv")

# %%
data
# Out:
#       CountryCode          subset question_code  \
# 0         Austria         Lesbian            e1
# 1         Austria         Lesbian            e1
# 2         Austria         Lesbian            e1
# 3         Austria         Lesbian            e1
# 4         Austria             Gay            e1
# 5         Austria             Gay            e1
# 6         Austria             Gay            e1
# 7         Austria             Gay            e1
# 8         Austria  Bisexual women            e1
# 9         Austria  Bisexual women            e1
# 10        Austria  Bisexual women            e1
# 11        Austria  Bisexual women            e1
# 12        Austria    Bisexual men            e1
# 13        Austria    Bisexual men            e1
# 14        Austria    Bisexual men            e1
# 15        Austria    Bisexual men            e1
# 16        Austria     Transgender            e1
# 17        Austria     Transgender            e1
# ...

# %%
data=data.dropna()

# %%
sns.heatmap(data.isnull(),yticklabels=True,cbar=True,cmap='viridis')
